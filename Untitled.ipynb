# %%
for i in range(1, 11):
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(1, 11):
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
numbers = [4, 15, 22, 8, 33, 7, 19]
for i in numbers:
    if i < 10:
        continue
    print(i)
# Out:
# 15
# 22
# 33
# 19

# %%
numbers = [3, 7, 12, 5, 18, 9, 25, 4]
for x in numbers:
  if x < 5:
    continue
  if x > 20:
   break
  print(x)
# Out:
# 7
# 12
# 5
# 18
# 9

# %%
orders = ["Латте", "Пропущенный", "Капучино", "Американо", "Отменённый", "Раф", "Эспрессо"]
for order in orders:
    if order == ("Пропущенный"):
        continue
    if order == ("Отменённый"):
        break
    print(f"Готовим:{order}")
print("Обработка завершена, спасибо за ожидание!")
# Out:
# Готовим:Латте
# Готовим:Капучино
# Готовим:Американо
# Обработка завершена, спасибо за ожидание!
